# %% [markdown]
# # 04 — Explainability
# Inspect model coefficients and model-agnostic permutation importance generated by `run_pipeline.py`.

# %%
from pathlib import Path
import pandas as pd
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
coef=pd.read_csv(ROOT/'reports/logistic_coefficients.csv'); perm=pd.read_csv(ROOT/'reports/permutation_importance.csv')
coef.head(15), perm.head(10)

# %% [markdown]
# Interpretation is directional and associative, not causal. Business decisions should be tested with controlled retention experiments where possible.
