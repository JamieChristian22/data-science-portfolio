# %% [markdown]
# # 04 — Explainability, Governance & Monitoring

# %% [markdown]
# ## Global importance
#
# Permutation importance quantifies the loss in PR-AUC when a feature is disrupted.

# %%
import pandas as pd
pd.read_csv('../reports/permutation_importance.csv').head(10)

# %% [markdown]
# ## Governance
#
# Credit models require more than predictive performance: validation, compliance, monitoring, explainability, controls and human oversight.

# %% [markdown]
# ## Monitoring
#
# See `reports/monitoring_plan.md` and `reports/governance_and_fair_lending.md` for the portfolio governance layer.
