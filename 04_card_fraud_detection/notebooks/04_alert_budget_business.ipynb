# %% [markdown]
# # 04 — Alert Budget & Business Impact
#
# Measure fraud capture at different investigation capacities and review fraud-dollar impact.
#
# This notebook is part of a synthetic portfolio demonstration. Results should not be interpreted as production performance.

# %%
import pandas as pd, json
print(pd.read_csv('../reports/alert_budget_analysis.csv'))
json.load(open('../reports/business_impact.json'))

# %% [markdown]
# ## Interpretation
#
# Use the generated reports and figures alongside this notebook. Model selection, thresholds, and business assumptions are documented explicitly in the repository rather than hidden in notebook state.
